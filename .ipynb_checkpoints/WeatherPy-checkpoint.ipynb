# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
units = "metric"
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=" + units
# Define an empty list to fetch the weather data for each city
city_data=[]

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        print(city_lat,"checking")

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | stanley
# 54.868 checking
# Processing Record 2 of Set 1 | vallenar
# -28.5708 checking
# Processing Record 3 of Set 1 | ushuaia
# -54.8 checking
# Processing Record 4 of Set 1 | icano
# -28.9193 checking
# Processing Record 5 of Set 1 | hithadhoo
# -0.6 checking
# Processing Record 6 of Set 1 | howrah
# 22.5892 checking
# Processing Record 7 of Set 1 | coxen hole
# 16.3244 checking
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# -37.0676 checking
# Processing Record 9 of Set 1 | port alfred
# -33.5906 checking
# Processing Record 10 of Set 1 | tazacorte
# 28.629 checking
# Processing Record 11 of Set 1 | usinsk
# 65.9939 checking
# Processing Record 12 of Set 1 | tamanrasset
# 22.785 checking
# Processing Record 13 of Set 1 | yellowknife
# 62.456 checking
# Processing Record 14 of Set 1 | avarua
# -21.2078 checking
# Processing Record 15 of Set 1 | marysville
# 48.0518 checking
# ...

# %%
print(city_data)
# Out:
# [{'City': 'stanley', 'Lat': 54.868, 'Lng': -1.6985, 'Max Temp': 10.16, 'Humidity': 95, 'Cloudiness': 100, 'Wind Speed': 2.06, 'Country': 'GB', 'Date': 1698262710}, {'City': 'vallenar', 'Lat': -28.5708, 'Lng': -70.7581, 'Max Temp': 28.59, 'Humidity': 20, 'Cloudiness': 0, 'Wind Speed': 5.18, 'Country': 'CL', 'Date': 1698262842}, {'City': 'ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 9.81, 'Humidity': 57, 'Cloudiness': 75, 'Wind Speed': 8.75, 'Country': 'AR', 'Date': 1698262513}, {'City': 'icano', 'Lat': -28.9193, 'Lng': -65.3282, 'Max Temp': 18.53, 'Humidity': 71, 'Cloudiness': 98, 'Wind Speed': 4.42, 'Country': 'AR', 'Date': 1698262977}, {'City': 'hithadhoo', 'Lat': -0.6, 'Lng': 73.0833, 'Max Temp': 27.79, 'Humidity': 78, 'Cloudiness': 41, 'Wind Speed': 7.08, 'Country': 'MV', 'Date': 1698262856}, {'City': 'howrah', 'Lat': 22.5892, 'Lng': 88.3103, 'Max Temp': 26, 'Humidity': 89, 'Cloudiness': 20, 'Wind Speed': 1.54, 'Country': 'IN', 'Date': 1698262774}, {'City': 'coxen hole', 'Lat
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    stanley  54.8680  -1.6985     10.16        95         100        2.06
# 1   vallenar -28.5708 -70.7581     28.59        20           0        5.18
# 2    ushuaia -54.8000 -68.3000      9.81        57          75        8.75
# 3      icano -28.9193 -65.3282     18.53        71          98        4.42
# 4  hithadhoo  -0.6000  73.0833     27.79        78          41        7.08
#
#   Country        Date
# 0      GB  1698262710
# 1      CL  1698262842
# 2      AR  1698262513
# 3      AR  1698262977
# 4      MV  1698262856

# %%
# Export the City_Data into a csv
city_data_df.to_csv("Output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("Output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          stanley  54.8680  -1.6985     10.16        95         100
# 1         vallenar -28.5708 -70.7581     28.59        20           0
# 2          ushuaia -54.8000 -68.3000      9.81        57          75
# 3            icano -28.9193 -65.3282     18.53        71          98
# 4        hithadhoo  -0.6000  73.0833     27.79        78          41
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      GB  1698262710
# 1              5.18      CL  1698262842
# 2              8.75      AR  1698262513
# 3              4.42      AR  1698262977
# 4              7.08      MV  1698262856

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import datetime
# Build scatter plot for latitude vs. temperature
lat = city_data_df["Lat"]
temp = city_data_df["Max Temp"]
plt.scatter(lat,temp,edgecolors="black")

# Incorporate the other graph properties
data_date = datetime.date.fromtimestamp(city_data_df["Date"].values[0])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title(f'City Latitude vs. Max Temperature ({data_date})')
plt.grid()

# Save the figure
plt.savefig("Output/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat = city_data_df["Lat"]
hum = city_data_df["Humidity"]
plt.scatter(lat,hum,edgecolors="black")

# Incorporate the other graph properties
data_date = datetime.date.fromtimestamp(city_data_df["Date"].values[0])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'City Latitude vs. Humidity ({data_date})')
plt.grid()

# Save the figure
plt.savefig("Output/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat = city_data_df["Lat"]
cloud = city_data_df["Cloudiness"]
plt.scatter(lat,cloud,edgecolors="black")

# Incorporate the other graph properties
data_date = datetime.date.fromtimestamp(city_data_df["Date"].values[0])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'City Latitude vs. Cloudiness ({data_date})')
plt.grid()

# Save the figure
plt.savefig("Output/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat = city_data_df["Lat"]
wind = city_data_df["Wind Speed"]
plt.scatter(lat,wind,edgecolors="black")

# Incorporate the other graph properties
data_date = datetime.date.fromtimestamp(city_data_df["Date"].values[0])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'City Latitude vs. Wind speed ({data_date})')
plt.grid()


# Save the figure
plt.savefig("Output/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linregress_plots(x_val,y_val,xlabel,ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
    regress_values = x_val * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_val,y_val)
    plt.plot(x_val,regress_values,"r-")

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.annotate(line_eq,(0.2,0.2),xycoords='figure fraction',fontsize=15,color="red")
    
    print(f"The r-value is: {rvalue}")

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           stanley  54.8680  -1.6985     10.16        95         100
# 5            howrah  22.5892  88.3103     26.00        89          20
# 6        coxen hole  16.3244 -86.5366     26.60        89          75
# 9         tazacorte  28.6290 -17.9293     23.54        86          75
# 10           usinsk  65.9939  57.5281     -9.96        95          99
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      GB  1698262710
# 5              1.54      IN  1698262774
# 6              2.57      HN  1698262978
# 9              3.60      ES  1698262742
# 10             4.47      RU  1698262602

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 1                           vallenar -28.5708 -70.7581     28.59        20
# 2                            ushuaia -54.8000 -68.3000      9.81        57
# 3                              icano -28.9193 -65.3282     18.53        71
# 4                          hithadhoo  -0.6000  73.0833     27.79        78
# 7        edinburgh of the seven seas -37.0676 -12.3116     10.16        53
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 0        5.18      CL  1698262842
# 2                75        8.75      AR  1698262513
# 3                98        4.42      AR  1698262977
# 4                41        7.08      MV  1698262856
# 7                10        6.62      SH  1698262723

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
nh_lat = northern_hemi_df["Lat"]
y_val =  northern_hemi_df["Max Temp"] 
xlabel = "Latitude"
ylabel = "Max Temp"
linregress_plots(nh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: -0.8749333314053708

# %%
# Linear regression on Southern Hemisphere
sh_lat = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Max Temp"]
xlabel = "Latitude"
ylabel = "Max Temp"
linregress_plots(sh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: 0.7463883277940944

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_lat = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Humidity"]
ylabel = "Humidity"

linregress_plots(nh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: 0.242541727321215

# %%
# Southern Hemisphere
sh_lat = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Humidity"]
xlabel = "Latitude"
ylabel = "Humidity"
linregress_plots(sh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: 0.1160140092013951

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_lat = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Cloudiness"]
ylabel = "Cloudiness"

linregress_plots(nh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: 0.17664178990665735

# %%
# Southern Hemisphere
sh_lat = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Cloudiness"]
ylabel = "Cloudiness"

linregress_plots(sh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: 0.048027864790077986

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_lat = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Wind Speed"]
ylabel = "Wind Speed"

linregress_plots(nh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
sh_lat = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Wind Speed"]
ylabel = "Wind Speed"

linregress_plots(sh_lat,y_val,xlabel,ylabel)
# Out:
# The r-value is: -0.21150691616962775

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
